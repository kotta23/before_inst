# %% [markdown]
# # Python Modules
#
#     Consider a module to be the same as a code library. A file containing a set of functions you want to include
#     in your application.
#
# ### Create a Module
#     by saving a file.py
#
#
# ### Use a Module
#     Now we can use any module created or installed , by using the import statement
#      - a module can be used in the code by either :
#              1- import name_of_the_module
#              2- import name_of_the_module as mod (mod)is the name i want to use for this module
#              3- from name_of_the_module import specific_method (to import a certain function fro a module)

# %%
#my module.py
def greeting(name):
  print("Hello, " + name)

person1 = {
  "name": "John",
  "age": 36,
  "country": "Norway"
}

# %%
import datetime

x = datetime.datetime.now()
print(x)

# %%
import math as m

x = m.sqrt(64)

print(x)

# %%
from mymodule import person1 

print (person1["age"])

# %% [markdown]
# # File Handling
#
# ## opening file syntax
# ###### 1st syntax
#
#     file = open('geek.txt','w')
#
# ###### 2end syntax
#
#     with open("file.txt", "w") as f:
#
#
# #### option to open a file :
#
#     “ r “, for reading.
#     “ w “, for writing.
#     “ a “, for appending.
#     “ r+ “, for both reading and writing
#     " x " - Create - will create a file, returns an error if the file exist
#
# #### read lines from files :
#     - file.readlines() ( a method that returns a list containing each line in the file as a list item.)
#     - file.read() / file.read(5) (a method that returns the whole text, but you can also specify how many characters you want to return)
#
#
# #### close file
#     - file.close()
#     alawys close a file after wirte/read from it
#
# #### delete file
#     - import os
#     - os.remove("demofile.txt")
#
# #### Check if File exist
#     - if os.path.exists("demofile.txt"):
#     - os.remove("demofile.txt")
#
# #### Delete Folder
#     os.rmdir("myfolder")

# %%
# open file 
f = open("file.txt", "r")
print(f.read())
with open("file.txt", "r") as f_2:
    print(f_2.readline())

# %%
# write to file 

L = ["This is Delhi \n", "This is Paris \n", "This is London \n"] 

s = "Hello\n"
  
f.write(s)

# %%
# Writing multiple strings 
# at a time 
f.writelines(L)

# %%
#close file 

f.close()

# %%
#check if file exist

import os
if os.path.exists("../../execise_2/file.txt"):
  os.remove("file.txt")
else:
  print("The file does not exist")

# %%
# delete file

import os
os.remove("file.txt")

# %%
# delete folder

import os
os.rmdir("myfolder")

# %% [markdown]
# # Object Oriented Programming
#
#     Class is an object constructor, it creates a user-defined data structure, which holds its own data members and member functions, which can be accessed and used by creating an instance of that class. A class is like a blueprint for an object.
#
# ### class creation
#
#         - first chr of a class name should be capitalized as common knowldege
#
#         - if a variable declared insid of a class it's called attribute and can be accessed outside the class by (class_name.attr_name)
#
#         - if a function is created inside a class we call it a method and it can be accessed outside the class through (class name.method_name())
#
#         - __init__ method or constructor  it contains a collection of statements(i.e. instructions) that are executed at the time of Object creation.(Constructors are used to initialize the object’s state. Like methods)
#
#         - if a variable defined in __init__ method (constructor) we will call it instances (Instance variables are variables whose value is assigned inside a constructor or method with self whereas class variables are variables whose value is assigned in the class.
#
#         - Professionally we create a method to set/get the value of instances of class
#
# ##### Class Variables —
#         Declared inside the class definition (but outside any of the instance methods). They are
#         not tied to any particular object of the class, hence shared across all the objects of the class.
#         Modifying a class variable affects all objects instance at the same time.
#
# #####  Instance Variable —
#         Declared inside the constructor method of class (the __init__ method). They are tied to the particular object instance of the class, hence the contents of an instance variable are completely independent from one object instance to the other.
#
# ##### Protected members
#         are those members of the class that cannot be accessed outside the class but can be accessed from within the class and its subclasses.
#
# ##### Private members
#         the difference is that the class members declared private should neither be accessed outside the class nor by any base class
#
# #### differnece between Class or static variables & Instance or non-static variables
#             Class or static variables are shared by all objects. Instance or non-static variables are different for different objects (every object has a copy of it).

# %%
class Dog:  

    # any variabl defined in a class is called (attribute)
    animal = 'dog'  

    # __init_() is a method called Constructor 
    def __init__(self, breed, color = ""):  
        # Instance Variable      
        self.breed = breed 
        self.color = color                   
    
    # Any functions defined in a class is called (method)   
    def fun(self):  
        print("I'm a", self.breed) 
        print("I'm a", self.color) 
    
    # Adds an instance variable   
    def setColor(self, color):  
        self.color = color  
        
    # Retrieves instance variable      
    def getColor(self):      
        return self.color

# %%
# you can use a class as an object 
# Objects of Dog class  
Rodger = Dog("Pug", "brown")  
Buzo = Dog("Bulldog", "black")

# To Access a class attributes and method through objects

print(Rodger.animal)  #accessing an attribute

Rodger.fun() # accesing a method

print('Rodger details:')    
print('Rodger is a', Rodger.animal)  
print('Breed: ', Rodger.breed) 
print('Color: ', Rodger.color) 

print('\nBuzo details:')    
print('Buzo is a', Buzo.animal)  
print('Breed: ', Buzo.breed) 
print('Color: ', Buzo.color) 

# Class variables can be accessed using class  
# name also  
print("\nAccessing class variable using class name") 
print(Dog.animal)       


# get instances name by get method
print(Rodger.getColor())   

# set instanes name by set method
tayson = Dog("wolf")
tayson.setColor("black")
print(Rodger.getColor())

# %%
class Base:
    def __init__(self):
        #instance
        self.a = "GeeksforGeeks"
        # Protected member
        self._b = 2
        #privat member
        self.__c = "GeeksforGeeks"
 
# Creating a derived class
class Derived(Base):
    def __init__(self):
        # Calling constructor of
        # Base class
        Base.__init__(self)
        print("Calling instance member of base class: ")
        print(self.a)        
        print("Calling protected member of base class: ")
        print(self._b)
        print("Calling private member of base class: ")
        print(self.__c)


# Uncommenting obj2 = Derived() will
obj1 =  Derived() 
# Driver code
obj2 = Base()


# AttributeError
print(obj2.a)
print(obj2.b)
#print(obj2.c) 
# Uncommenting print(obj1.c) will
# raise an AttributeError

# %%
# Class for Computer Science Student 
class CSStudent: 
    stream = 'cse'                  # Class Variable 
    def __init__(self,name,roll): 
        self.name = name            # Instance Variable 
        self.roll = roll            # Instance Variable

# %%
# Objects of CSStudent class 
a = CSStudent('Geek', 1) 
b = CSStudent('Nerd', 2) 
  
print(a.stream)  # prints "cse" 
print(b.stream)  # prints "cse" 
print(a.name)    # prints "Geek" 
print(b.name)    # prints "Nerd" 
print(a.roll)    # prints "1" 
print(b.roll)    # prints "2" 
  
# Class variables can be accessed using class 
# name also 
print(CSStudent.stream) # prints "cse"

# %% [markdown]
# # inhertance
#         Inheritance is the capability of one class to derive or inherit the properties from another class.
#
#         - in inhertance if there a parent class has a  __init__ method  it should be initialized  in the child
#           class
#         - there are 3 types of inhertance :
#
#             1-  Single inheritance: When a child class inherits from only one parent class, it is called single
#                 inheritance. We saw an example above.
#
#             2- Multiple inheritance: When a child class inherits from multiple parent classes, it is called
#                multiple inheritance.
#
#             3- Multilevel inheritance: When we have a child and grandchild relationship.
#
#             4- Hierarchical Inheritance: When more than one derived classes are created from a single base this
#
# # polymorphism
#         means same function name (but different signatures) being uses for different types.

# %% [markdown]
# ![Hierarchical-inheritance1%20%281%29.jpg](attachment:Hierarchical-inheritance1%20%281%29.jpg)

# %%
#inhertance 

# Single inheritance:
class A: 
      def __init__(self, name): 
            self.name = name 
class B(A): 
      def __init__(self, roll , name): 
            self.roll = roll
            A.__init__(self,name) 
  
object = B(23,'asdsa') 
print (object.name)

# %%
# Multiple inheritance 
class Base1(object): 
    # Constructor
    def __init__(self): 
        self.str1 = "Geek1" #instance  
        print("Base1") 
  
class Base2(object): 
    # Constructor
    def __init__(self): 
        self.str2 = "Geek2"  #instance      
        print("Base2") 
  
class Derived(Base1, Base2): 
    # Constructor
    def __init__(self): 
          
        # Calling constructors of Base1 
        # and Base2 classes 
        Base1.__init__(self) 
        Base2.__init__(self) 
        print("Derived") 
    # Method      
    def printStrs(self): 
        print(self.str1, self.str2) 
         
  
ob = Derived() 
ob.printStrs()

# %%
# Multilevel inheritance

class Base(object): 
      
    # Constructor 
    def __init__(self, name): 
        self.name = name 
  
    # To get name 
    def getName(self): 
        return self.name 
  
  
# Inherited or Sub class (Note Person in bracket) 
class Child(Base): 
      
    # Constructor 
    def __init__(self, name, age): 
        Base.__init__(self, name) 
        self.age = age 
  
    # To get name 
    def getAge(self): 
        return self.age 
  
# Inherited or Sub class (Note Person in bracket) 
class GrandChild(Child): 
      
    # Constructor 
    def __init__(self, name, age, address): 
        Child.__init__(self, name, age) 
        self.address = address 
  
    # To get address 
    def getAddress(self): 
        return self.address         
  
# Driver code 
g = GrandChild("Geek1", 23, "Noida")   
print(g.getName(), g.getAge(), g.getAddress())

# %%
# Hierarchical inheritance
 
 
# Base class
class Parent:
      def func1(self):
          print("This function is in parent class.")
 
# Derived class1
class Child1(Parent):
      def func2(self):
          print("This function is in child 1.")
 
# Derivied class2
class Child2(Parent):
      def func3(self):
          print("This function is in child 2.")
  
# Driver's code
object1 = Child1()
object2 = Child2()
object1.func1()
object1.func2()
object2.func1()
object2.func3()

# %%
# Method Overriding.
class Bird: 
  def intro(self): 
    print("There are many types of birds.") 
      
  def flight(self): 
    print("Most of the birds can fly but some cannot.") 
    
class sparrow(Bird): 
  def flight(self): 
    print("Sparrows can fly.") 
      
class ostrich(Bird): 
  def flight(self): 
    print("Ostriches cannot fly.") 
      
obj_bird = Bird() 
obj_spr = sparrow() 
obj_ost = ostrich() 
  
obj_bird.intro() 
obj_bird.flight() 
  
obj_spr.intro() 
obj_spr.flight() 
  
obj_ost.intro() 
obj_ost.flight()
